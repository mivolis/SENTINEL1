# %%
pip install numpy==1.26.4
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp39-cp39-macosx_10_9_x86_64.whl.metadata (61 kB)
# Downloading numpy-1.26.4-cp39-cp39-macosx_10_9_x86_64.whl (20.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 15.5 MB/s eta 0:00:00a 0:00:01
# WARNING: Error parsing dependencies of pybind11: [Errno 2] No such file or directory: '/Users/huyutong/opt/anaconda3/lib/python3.9/site-packages/pybind11-2.10.4.dist-info/METADATA'
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# fasttext 0.9.2 requires pybind11>=2.2, which is not installed.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.26.4 which is incompatible.
# scipy 1.9.1 requires numpy<1.25.0,>=1.18.5, but you have numpy 1.26.4 which is incompatible.
# torchaudio 2.2.0 requires torch==2.2.0, but you have torch 1.8.0 which is incompatible.
# torchvision 0.17.0 requires torch==2.2.0, but you have torch 1.8.0 which is incompatible.
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python==4.10.0.84
# Out:
# Collecting opencv-python==4.10.0.84
#   Downloading opencv_python-4.10.0.84-cp37-abi3-macosx_12_0_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17.0 in /Users/huyutong/opt/anaconda3/lib/python3.9/site-packages (from opencv-python==4.10.0.84) (1.26.4)
# Downloading opencv_python-4.10.0.84-cp37-abi3-macosx_12_0_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 14.4 MB/s eta 0:00:00a 0:00:01
# WARNING: Error parsing dependencies of pybind11: [Errno 2] No such file or directory: '/Users/huyutong/opt/anaconda3/lib/python3.9/site-packages/pybind11-2.10.4.dist-info/METADATA'
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.84
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
# Out:
# /Users/huyutong/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
pip install --upgrade numexpr
# Out:
# Requirement already satisfied: numexpr in /Users/huyutong/opt/anaconda3/lib/python3.9/site-packages (2.8.3)
# Collecting numexpr
#   Downloading numexpr-2.10.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: numpy>=1.23.0 in /Users/huyutong/opt/anaconda3/lib/python3.9/site-packages (from numexpr) (1.26.4)
# Downloading numexpr-2.10.1-cp39-cp39-macosx_10_9_x86_64.whl (141 kB)
# WARNING: Error parsing dependencies of pybind11: [Errno 2] No such file or directory: '/Users/huyutong/opt/anaconda3/lib/python3.9/site-packages/pybind11-2.10.4.dist-info/METADATA'
# Installing collected packages: numexpr
#   Attempting uninstall: numexpr
#     Found existing installation: numexpr 2.8.3
#     Uninstalling numexpr-2.8.3:
#       Successfully uninstalled numexpr-2.8.3
# Successfully installed numexpr-2.10.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas==2.1.4
# Out:
# Collecting pandas==2.1.4
#   Downloading pandas-2.1.4-cp39-cp39-macosx_10_9_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/huyutong/opt/anaconda3/lib/python3.9/site-packages (from pandas==2.1.4) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/huyutong/opt/anaconda3/lib/python3.9/site-packages (from pandas==2.1.4) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/huyutong/opt/anaconda3/lib/python3.9/site-packages (from pandas==2.1.4) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/huyutong/opt/anaconda3/lib/python3.9/site-packages (from pandas==2.1.4) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/huyutong/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas==2.1.4) (1.16.0)
# Downloading pandas-2.1.4-cp39-cp39-macosx_10_9_x86_64.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 15.2 MB/s eta 0:00:00 0:00:01
# WARNING: Error parsing dependencies of pybind11: [Errno 2] No such file or directory: '/Users/huyutong/opt/anaconda3/lib/python3.9/site-packages/pybind11-2.10.4.dist-info/METADATA'
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
# Successfully installed pandas-2.1.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
file = '/Users/huyutong/Desktop/may/HKUST/TERM/Y2S/O/get_labels/merged_data.csv'

# %%
data = pd.read_csv(file, sep=',',header=0)

# %%
data
# Out:
#              key_0  Compound ID Uniprot Target           Name  \
# 0      118796358.0            1  Q9NPI1   BRD7        BI-7273
# 1      118796358.0            1  Q9H8M2   BRD9        BI-7273
# 2      117072549.0            2  Q9NPI1   BRD7        BI-9564
# 3      117072549.0            2  Q9NPI1   BRD7        BI-9564
# 4      117072549.0            2  Q9H8M2   BRD9        BI-9564
# ...            ...          ...     ...    ...            ...
# 13933       5743.0          561  P04150     GR  Dexamethasone
# 13934       5743.0          561  P04150     GR  Dexamethasone
# 13935       5743.0          561  P04150     GR  Dexamethasone
# 13936       5743.0          561  P04150     GR  Dexamethasone
# 13937       5743.0          561  P04150     GR  Dexamethasone
#
#                                                   Smiles IC50 (nM)  \
# 0      COC1=CC(C2=CN(C)C(=O)C3=CN=CC=C23)=CC(OC)=C1CN...       117
# 1      COC1=CC(C2=CN(C)C(=O)C3=CN=CC=C23)=CC(OC)=C1CN...        19
# 2      COC1=CC(C2=CN(C)C(=O)C3=CN=CC=C23)=C(OC)C=C1CN...      3410
# 3      COC1=CC(C2=CN(C)C(=O)C3=CN=CC=C23)=C(OC)C=C1CN...      3410
# 4      COC1=CC(C2=CN(C)C(=O)C3=CN=CC=C23)=C(OC)C=C1CN...        75
# ...                                                  ...       ...
# 13933  C[C@@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C...       NaN
# 13934  C[C@@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C...       NaN
# 13935  C[C@@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C...       NaN
# 13936  C[C@@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C...       NaN
# 13937  C[C@@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C...       NaN
#
#                     Assay (IC50)  EC50 (nM) Assay (EC50)  ...  \
# 0      BRD7 H3 AlphaScreen assay        NaN          NaN  ...
# 1      BRD9-H3 AlphaScreen assay        NaN          NaN  ...
# 2      BRD7 H3 AlphaScreen assay        NaN          NaN  ...
# 3      BRD7 H3 AlphaScreen assay        NaN          NaN  ...
# 4      BRD9-H3 AlphaScreen assay        NaN          NaN  ...
# ...                          ...        ...          ...  ...
# 13933                        NaN        NaN          NaN  ...
# 13934                        NaN        NaN          NaN  ...
# 13935                        NaN        NaN          NaN  ...
# 13936                        NaN        NaN          NaN  ...
# 13937                        NaN        NaN          NaN  ...
#
#       interaction_score     drug_claim_name     drug_concept_id  \
# 0              6.563459  IUPHAR.LIGAND:9146  iuphar.ligand:9146
# 1              6.563459  IUPHAR.LIGAND:9146  iuphar.ligand:9146
# 2              8.751279  IUPHAR.LIGAND:8950  iuphar.ligand:8950
# 3              3.281729  IUPHAR.LIGAND:8950  iuphar.ligand:8950
# 4              8.751279  IUPHAR.LIGAND:8950  iuphar.ligand:8950
# ...                 ...                 ...                 ...
# 13933          0.015859       DEXAMETHASONE          rxcui:3264
# 13934          0.029074       DEXAMETHASONE          rxcui:3264
# 13935          0.029074       DEXAMETHASONE          rxcui:3264
# 13936          0.203518       DEXAMETHASONE          rxcui:3264
# 13937          1.221109       DEXAMETHASONE          rxcui:3264
#
#            drug_name approved  immunotherapy  anti_neoplastic    data_source  \
# 0            BI-7273    False          False            False  iuphar.ligand
# 1            BI-7273    False          False            False  iuphar.ligand
# 2            BI-9564    False          False            False  iuphar.ligand
# 3            BI-9564    False          False            False  iuphar.ligand
# 4            BI-9564    False          False            False  iuphar.ligand
# ...              ...      ...            ...              ...            ...
# 13933  DEXAMETHASONE     True          False             True          rxcui
# 13934  DEXAMETHASONE     True          False             True          rxcui
# 13935  DEXAMETHASONE     True          False             True          rxcui
# 13936  DEXAMETHASONE     True          False             True          rxcui
# 13937  DEXAMETHASONE     True          False             True          rxcui
#
#        source_id        PubID
# 0           9146  118796358.0
# 1           9146  118796358.0
# 2           8950  117072549.0
# 3           8950  117072549.0
# 4           8950  117072549.0
# ...          ...          ...
# 13933       3264       5743.0
# 13934       3264       5743.0
# 13935       3264       5743.0
# 13936       3264       5743.0
# 13937       3264       5743.0
#
# [13938 rows x 46 columns]

# %%
unique_ids = data['key_0'].unique()

# %%
unique_ids
# Out:
# array([1.18796358e+08, 1.17072549e+08, 4.49459000e+05, 2.73352600e+06,
#        4.69077870e+07, 9.82456200e+06, 2.51171260e+07, 5.42600000e+03,
#        1.16473720e+07, 1.60381200e+07, 5.74068530e+07, 1.13380330e+07,
#        4.44795000e+05, 7.14626530e+07, 1.06350000e+04, 3.02598600e+06,
#        6.69370060e+07, 1.18414016e+08, 1.13644210e+07, 4.41296600e+07,
#        9.82652800e+06, 2.48573230e+07, 4.69080260e+07, 2.48564360e+07,
#        1.19605290e+07, 5.35134400e+06, 4.87800000e+03, 1.33081964e+08,
#        1.04618150e+07, 1.17131590e+07, 2.20499970e+07, 5.94475770e+07,
#        1.34457640e+08, 9.04662610e+07, 6.82101020e+07, 1.16767860e+07,
#        9.00523200e+07, 5.85391710e+07, 2.50737750e+07, 4.89300000e+03,
#        5.33079000e+06, 7.27068400e+07, 7.82437520e+07, 5.32624010e+07,
#        9.02416730e+07, 7.33339760e+07, 5.31151000e+06, 1.60400670e+07,
#        7.70506820e+07, 2.49646240e+07, 1.56414000e+05, 1.18238370e+08,
#        9.16233600e+07, 4.98679290e+07, 1.67257260e+07, 1.32010322e+08,
#        6.04700000e+03, 1.67476830e+07, 1.56775102e+08, 1.67365290e+07,
#        1.01389800e+07, 1.45996540e+08, 4.44493340e+07, 2.16345000e+05,
#        5.32320000e+04, 4.47905000e+05, 1.21410806e+08, 1.22724000e+05,
#        5.28838200e+06, 3.95620000e+04, 3.68941300e+06, 1.76158000e+05,
#        1.31986624e+08, 1.29045720e+08, 4.45639000e+05, 2.47482040e+07,
#        1.38911318e+08, 1.21328278e+08, 7.16043070e+07, 5.10390950e+07,
#        2.52682000e+05, 5.85393010e+07, 9.93434700e+06, 1.37278711e+08,
#        1.26941000e+05, 1.01680000e+04, 2.47950700e+07, 5.84231530e+07,
#        4.48144090e+07, 5.74300000e+03])

# %%
import numpy as np
index_array = np.array([], dtype=int)

# Deduplicate another column under the same ID
for id in unique_ids:
    instance = data[data['key_0'] == id]
    instance = instance['gene_name'].astype(str)
    instance = instance.drop_duplicates(keep='first')
    ind = instance.index
    index_array = np.concatenate((index_array, ind))

# %%
index_array
# Out:
# array([    0,     2,     3, ..., 13935, 13936, 13937])

# %%
data = data.loc[index_array]

# %%
data['key_0'] = data['key_0'].astype(int)

# %%
data
# Out:
#            key_0  Compound ID Uniprot Target           Name  \
# 0      118796358            1  Q9NPI1   BRD7        BI-7273
# 2      117072549            2  Q9NPI1   BRD7        BI-9564
# 3      117072549            2  Q9NPI1   BRD7        BI-9564
# 6         449459            7  P03372     ER    Afimoxifene
# 7         449459            7  P03372     ER    Afimoxifene
# ...          ...          ...     ...    ...            ...
# 13931       5743          561  P04150     GR  Dexamethasone
# 13933       5743          561  P04150     GR  Dexamethasone
# 13935       5743          561  P04150     GR  Dexamethasone
# 13936       5743          561  P04150     GR  Dexamethasone
# 13937       5743          561  P04150     GR  Dexamethasone
#
#                                                   Smiles IC50 (nM)  \
# 0      COC1=CC(C2=CN(C)C(=O)C3=CN=CC=C23)=CC(OC)=C1CN...       117
# 2      COC1=CC(C2=CN(C)C(=O)C3=CN=CC=C23)=C(OC)C=C1CN...      3410
# 3      COC1=CC(C2=CN(C)C(=O)C3=CN=CC=C23)=C(OC)C=C1CN...      3410
# 6      CC/C(=C(\C1=CC=C(O)C=C1)C1=CC=C(OCCN(C)C)C=C1)...       NaN
# 7      CC/C(=C(\C1=CC=C(O)C=C1)C1=CC=C(OCCN(C)C)C=C1)...       NaN
# ...                                                  ...       ...
# 13931  C[C@@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C...       NaN
# 13933  C[C@@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C...       NaN
# 13935  C[C@@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C...       NaN
# 13936  C[C@@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C...       NaN
# 13937  C[C@@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C...       NaN
#
#                     Assay (IC50)  EC50 (nM) Assay (EC50)  ...  \
# 0      BRD7 H3 AlphaScreen assay        NaN          NaN  ...
# 2      BRD7 H3 AlphaScreen assay        NaN          NaN  ...
# 3      BRD7 H3 AlphaScreen assay        NaN          NaN  ...
# 6                            NaN        NaN          NaN  ...
# 7                            NaN        NaN          NaN  ...
# ...                          ...        ...          ...  ...
# 13931                        NaN        NaN          NaN  ...
# 13933                        NaN        NaN          NaN  ...
# 13935                        NaN        NaN          NaN  ...
# 13936                        NaN        NaN          NaN  ...
# 13937                        NaN        NaN          NaN  ...
#
#       interaction_score     drug_claim_name     drug_concept_id  \
# 0              6.563459  IUPHAR.LIGAND:9146  iuphar.ligand:9146
# 2              8.751279  IUPHAR.LIGAND:8950  iuphar.ligand:8950
# 3              3.281729  IUPHAR.LIGAND:8950  iuphar.ligand:8950
# 6              0.087630         Afimoxifene           ncit:C975
# 7              0.035052         AFIMOXIFENE           ncit:C975
# ...                 ...                 ...                 ...
# 13931          0.087222       DEXAMETHASONE          rxcui:3264
# 13933          0.015859       DEXAMETHASONE          rxcui:3264
# 13935          0.029074       DEXAMETHASONE          rxcui:3264
# 13936          0.203518       DEXAMETHASONE          rxcui:3264
# 13937          1.221109       DEXAMETHASONE          rxcui:3264
#
#            drug_name approved  immunotherapy  anti_neoplastic    data_source  \
# 0            BI-7273    False          False            False  iuphar.ligand
# 2            BI-9564    False          False            False  iuphar.ligand
# 3            BI-9564    False          False            False  iuphar.ligand
# 6        AFIMOXIFENE    False          False             True           ncit
# 7        AFIMOXIFENE    False          False             True           ncit
# ...              ...      ...            ...              ...            ...
# 13931  DEXAMETHASONE     True          False             True          rxcui
# 13933  DEXAMETHASONE     True          False             True          rxcui
# 13935  DEXAMETHASONE     True          False             True          rxcui
# 13936  DEXAMETHASONE     True          False             True          rxcui
# 13937  DEXAMETHASONE     True          False             True          rxcui
#
#        source_id        PubID
# 0           9146  118796358.0
# 2           8950  117072549.0
# 3           8950  117072549.0
# 6           C975     449459.0
# 7           C975     449459.0
# ...          ...          ...
# 13931       3264       5743.0
# 13933       3264       5743.0
# 13935       3264       5743.0
# 13936       3264       5743.0
# 13937       3264       5743.0
#
# [1224 rows x 46 columns]

# %%
data.to_csv('merge_deduplicate.csv', index=True, decimal=',')
